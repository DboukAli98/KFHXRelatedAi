# %%
import os
from pathlib import Path
# Setting the working directory to the root of the project
project_dir = Path("C:/Users/adbou/source/repos/KFHXRelatedAi/")
os.chdir(project_dir)

from Configs.GeneralPaths import SOURCEDATA
import pandas as pd

# %%
#loading the csv into pandas df

cleaned_deals_path = SOURCEDATA / "Cleaned_Deals.xlsx"

deals = pd.read_excel(cleaned_deals_path)

# %%
deals = deals.drop(columns=['Unnamed: 0'])
deals.head()
# Out:
#    ContentId                                   Title  FK_StatusId  \
# 0     113815                       Off from Al Rifai            2
# 1     113816                      Off from Dip n dip            2
# 2     113817  Order from Dip n Dip and get  discount            1
# 3     113818        Get  discount from Ellena Bakery            2
# 4     113819                        Off from Talabat            1
#
#        Deal Type                                        Description  \
# 0  15 KD Voucher  Get a 15 KD discount voucher for your next onl...
# 1  10 KD Voucher  Get 10 KD off on your next order from Dip n di...
# 2   5KD discount          Order from Dip n Dip and get 5KD discount
# 3   3KD discount                Get 3KD discount from Ellena Bakery
# 4   3 KD Voucher                     Get 3KD discount from Talabat.
#
#                                             Location  Points Categories
# 0  https://www.google.com/maps/search/al+rifai+ku...   15000        F&B
# 1                                                NaN   10000        F&B
# 2  https://www.google.com/maps/search/dipndip/@29...    5000        F&B
# 3          https://maps.app.goo.gl/bnZXdfUbbaGFjFiJA    3000        F&B
# 4              https://goo.gl/maps/5uoJEdD95W1YSpDt9    3000        F&B

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.countplot(data=deals, x='Categories')
plt.xlabel('Categories')
plt.ylabel('Count of ContentId')
plt.title('Count of ContentId for Each Category')
plt.show()

# %%
on_demand_deals = deals[deals['Categories'] == 'On-demand']
on_demand_deals
# Out:
#      ContentId                                Title  FK_StatusId  \
# 23      113838                 10% Off from One Use            2
# 37      113852                   Off from H&S Store            2
# 42      113857            Up to 45% Off from Cambly            2
# 43      113858                   10% Off from Vinco            2
# 50      113865        15% Off from The Healthy Home            2
# 51      113866        10% Off from The Healthy Home            2
# 52      113867                      off from BeWear            2
# 61      113876   Recharge your Pass App wallet with            1
# 62      113877           25% off from Nishan clinic            2
# 68      113883            Get  discount from V-Thru            2
# 69      113884            Deliveroo Wallet recharge            2
# 73      113888  20% off on Bleach Cleaning Services            2
# 84      113899          Get a  voucher from Mr. Fix            2
# 91      113906                15% off on Timeviewer            2
# 99      113914                   15% Off from Srvme            2
# 100     113915  Recharge your Deliveroo wallet with            1
# 104     113919                    off on MyHome App            2
# 105     113920                    off on MyHome App            2
# 186     115209                         from Ooredoo            1
# 187     115211                            from Zain            1
# 188     115213                             from STC            1
#
#                  Deal Type                                        Description  \
# 23              % Discount  Get 10% off on all orders from One Use. Valid ...
# 37           20 KD Voucher  Get a 20 KD discount on your next order from H...
# 42              % Discount  Get 45% off 12-month plans and&nbsp;33% off 3-...
# 43              % Discount  Get 10% off on your next purchase from VINCO a...
# 50              % Discount  Get 15% off on Mattresses, Soft Furnishings Cl...
# 51              % Discount  Get 10% off on Duct Cleaning and Sanitization,...
# 52            2 KD Voucher  Get 2 KD off on everything from BeWear, the tr...
# 61    Wallet Recharge 3 KD             Recharge your Pass App wallet with 3KD
# 62            25% Discount  Rejuvenate with 25% off on all services from N...
# 68            1KD discount                       Get 1KD discount from V-Thru
# 69   25 KD Wallet Recharge           Recharge your Deliveroo wallet with 25KD
# 73              % Discount  20% off on the detailed cleaning, furniture cl...
# 84                 Voucher  Bring life back to your gadgets and take a KD ...
# 91            15% Discount  Pick any Online Consultation (medical or other...
# 99            15% Discount  Get 15% off on all services from Srvme. -- cop...
# 100   3 KD Wallet Recharge            Recharge your Deliveroo wallet with 3KD
# 104           5 KD Voucher  Get a 5 KD off on your order value from MyHome...
# 105          10 KD Voucher  Get a 10 KD off on your order value from MyHom...
# 186      Ooredoo Gift Card  Get a 5 KD Ooredoo Gift Card to be used for yo...
# 187         Zain Gift Card  Get a 5 KD Zain Gift Card to be used for your ...
# 188          STC Gift Card  Get a 5 KD STC Gift Card to be used for your n...
#
#                                               Location  Points Categories
# 23               https://goo.gl/maps/o6uQebnsW3LABM1Q7     500  On-demand
# 37                   https://www.hsstore.com/showrooms   20000  On-demand
# 42                https://www.instagram.com/cambly_ar/    1500  On-demand
# 43                https://www.instagram.com/letsvinco/     500  On-demand
# 50         https://thehealthyhome.me/kuwait/contact-us    1000  On-demand
# 51         https://thehealthyhome.me/kuwait/contact-us     500  On-demand
# 52                 https://www.instagram.com/bewearkw/    1000  On-demand
# 61          https://apps.apple.com/us/app/id1435687530    3000  On-demand
# 62   https://www.google.com/maps/place/Nishan+Medic...    1000  On-demand
# 68           https://maps.app.goo.gl/qGDMPAmGZaMU3YvX6    1000  On-demand
# 69             https://www.instagram.com/deliveroo_kw/   25000  On-demand
# 73                               http://bleach-kw.com/     500  On-demand
# 84   https://www.google.com/maps/place/Mr.+Fix/@29....    1000  On-demand
# 91            https://www.instagram.com/timeviewer.tv/    1000  On-demand
# 99       https://www.instagram.com/srvme.kuwait/?hl=en    1000  On-demand
# 100            https://www.instagram.com/deliveroo_kw/    3000  On-demand
# 104                      https://myhome.app/kw/en/home    5000  On-demand
# 105                      https://myhome.app/kw/en/home   10000  On-demand
# 186                                                NaN    5000  On-demand
# 187                                                NaN    5000  On-demand
# 188                                                NaN    5000  On-demand
