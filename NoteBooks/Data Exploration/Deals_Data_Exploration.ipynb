# %%
import os
from pathlib import Path
# Setting the working directory to the root of the project
project_dir = Path("C:/Users/adbou/source/repos/KFHXRelatedAi/")
os.chdir(project_dir)

from Configs.GeneralPaths import SOURCEDATA
import pandas as pd

# %%
#loading the csv into pandas df

cleaned_deals_path = SOURCEDATA / "Cleaned_Deals.xlsx"

deals = pd.read_excel(cleaned_deals_path)

# %%
deals = deals.drop(columns=['Unnamed: 0'])
deals.head()
# Out:
#    ContentId                                   Title  FK_StatusId Deal Type  \
# 0     113815                       Off from Al Rifai            2   Voucher
# 1     113816                      Off from Dip n dip            2   Voucher
# 2     113817  Order from Dip n Dip and get  discount            1  Discount
# 3     113818        Get  discount from Ellena Bakery            2  Discount
# 4     113819                        Off from Talabat            1   Voucher
#
#                                          Description  \
# 0  Get a 15 KD discount voucher for your next onl...
# 1  Get 10 KD off on your next order from Dip n di...
# 2  Order from Dip n Dip and get 5KD discount enjo...
# 3  Get 3KD discount from Ellena Bakery . Ellena b...
# 4  Get 3KD discount from Talabat. Talabat is an o...
#
#                                             Location  Points Categories
# 0  https://www.google.com/maps/search/al+rifai+ku...   15000        F&B
# 1                                                NaN   10000        F&B
# 2  https://www.google.com/maps/search/dipndip/@29...    5000        F&B
# 3          https://maps.app.goo.gl/bnZXdfUbbaGFjFiJA    3000        F&B
# 4              https://goo.gl/maps/5uoJEdD95W1YSpDt9    3000        F&B

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.countplot(data=deals, x='Categories')
plt.xlabel('Categories')
plt.ylabel('Count of ContentId')
plt.title('Count of ContentId for Each Category')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.countplot(data=deals, x='Deal Type')
plt.xlabel('Deal Type')
plt.ylabel('Count of ContentId')
plt.title('Count of ContentId for Each Deal Type')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=deals, x='FK_StatusId')
plt.xlabel('Status Id')
plt.ylabel('Count of Status Id')
plt.title('Count of ContentId for Each Status Id')
plt.show()

# %%
on_demand_deals = deals[deals['Categories'] == 'Automotive']
on_demand_deals
# Out:
#      ContentId                                        Title  FK_StatusId  \
# 5       113820                            Off from Mikaniki            2
# 6       113821  10% Off on Motor Insurance from KFH Takaful            2
# 14      113829                Get 15% discount from Ghaseel            1
# 71      113886                       Get 20% from Kromozone            2
# 75      113890              Get Flat  off from FK Autoparts            2
# 102     113917                      10% off from Motery App            2
# 139     115094                        30% off from Car Spa!            1
#
#     Deal Type                                        Description  \
# 5     Voucher  Get 2 KD Mikaniki is a car service company tha...
# 6    Discount  If you have a motor and need an insurance for ...
# 14   Discount  Get 15% discount from Ghaseel wash your car an...
# 71   Discount  Get 20% on all services and products from Krom...
# 75    Voucher  Flat 3 KD off on the best quality car autopart...
# 102  Discount  Download Motery app and get 10% off on all ser...
# 139  Discount                        Enjoy 30% off from Car Spa.
#
#                                       Location  Points  Categories
# 5       https://www.instagram.com/mikaniki.kw/     500  Automotive
# 6    https://maps.app.goo.gl/iTLwkPKNmNcFi5ia8    1000  Automotive
# 14          https://www.instagram.com/ghaseel/      50  Automotive
# 71       https://goo.gl/maps/Tafu81EJidS7C3SE9    1000  Automotive
# 75       https://goo.gl/maps/JNFBSHGq5nSxJxmR8    1000  Automotive
# 102       https://www.instagram.com/moterykwt/    1000  Automotive
# 139  https://maps.app.goo.gl/oaPZdGGPm9yWycgR9     100  Automotive

# %%
specific_content_id = 113877 
result = deals[deals['ContentId'] == specific_content_id]

result
# Out:
#     ContentId                       Title  FK_StatusId Deal Type  \
# 62     113877  25% off from Nishan clinic            2  Discount
#
#                                           Description  \
# 62  Rejuvenate with 25% off on all services from N...
#
#                                              Location  Points Categories
# 62  https://www.google.com/maps/place/Nishan+Medic...    1000  On-demand
