# %%
import os
from pathlib import Path
# Setting the working directory to the root of the project
project_dir = Path("C:/Users/adbou/source/repos/KFHXRelatedAi/")
os.chdir(project_dir)

from Configs.GeneralPaths import SOURCEDATA
import pandas as pd

# %%
#loading the csv into pandas df

cleaned_deals_path = SOURCEDATA / "Rdepemtion_Cleaned_Deals.xlsx"

deals = pd.read_excel(cleaned_deals_path)

# %%
deals = deals.drop(columns=['Unnamed: 0.1'])
deals.head()
# Out:
#    Unnamed: 0  ContentId                                   Title  FK_StatusId  \
# 0           0     113815                       Off from Al Rifai            2
# 1           1     113816                      Off from Dip n dip            2
# 2           2     113817  Order from Dip n Dip and get  discount            1
# 3           3     113818        Get  discount from Ellena Bakery            2
# 4           4     113819                        Off from Talabat            1
#
#   Deal Type                                        Description  \
# 0   Voucher  Get a 15 KD discount voucher for your next onl...
# 1   Voucher  Get 10 KD off on your next order from Dip n di...
# 2  Discount          Order from Dip n Dip and get 5KD discount
# 3  Discount                Get 3KD discount from Ellena Bakery
# 4   Voucher                     Get 3KD discount from Talabat.
#
#                                             Location  Points  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.countplot(data=deals, x='Categories')
plt.xlabel('Categories')
plt.ylabel('Count of ContentId')
plt.title('Count of ContentId for Each Category')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.countplot(data=deals, x='Deal Type')
plt.xlabel('Deal Type')
plt.ylabel('Count of ContentId')
plt.title('Count of ContentId for Each Deal Type')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=deals, x='FK_StatusId')
plt.xlabel('Status Id')
plt.ylabel('Count of Status Id')
plt.title('Count of ContentId for Each Status Id')
plt.show()

# %%
on_demand_deals = deals[deals['Categories'] == 'Automotive']
on_demand_deals
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ContentId, Title, FK_StatusId, Deal Type, Description, Location, Points, Categories]
# Index: []

# %%
specific_content_id = 115094 
result = deals[deals['ContentId'] == specific_content_id]

result
# Out:
#      Unnamed: 0  ContentId                  Title  FK_StatusId Deal Type  \
# 139         139     115094  30% off from Car Spa!            1  Discount
#
#                      Description                                   Location  \
# 139  Enjoy 30% off from Car Spa.  https://maps.app.goo.gl/oaPZdGGPm9yWycgR9
#
#      Points           Categories
# 139     100  Automotive Services
