# %%
import os
import sys
from pathlib import Path
# Setting the working directory to the root of the project
project_dir = Path("C:/Users/adbou/source/repos/KFHXRelatedAi/")
os.chdir(project_dir)

from Configs.GeneralPaths import SOURCEDATA
import pandas as pd
import numpy as np

# %%
#load user transactions data
transactions = pd.read_excel(Path(SOURCEDATA / "Transactions_Collab.xlsx"))

# %%
transactions.head()
# Out:
#       TrxId                 TrxDate  FK_BusinessUserId  PointsRedeemed  \
# 0  12429817 2023-06-04 11:46:06.050             976480            1000
# 1  12525687 2023-06-07 14:08:10.287             976480           10000
# 2  12525666 2023-06-08 11:03:32.043             976480           10000
# 3  12838074 2023-06-22 08:28:30.300             976921              10
# 4  13587992 2023-07-27 14:41:13.607             976480              50
#
#         EntityName  FK_ContentId   EntityCategory
# 0  Alkhalid Clinic      113923.0  Health & Beauty
# 1        H&S Store      113853.0      Electronics
# 2        H&S Store      113853.0      Electronics
# 3   Deliveroo Plus      113851.0  Food & Beverage
# 4       Mawqif App      113835.0        On-demand

# %%
# Count the number of missing values in 'FK_ContentId'
missing_values_count = transactions['FK_ContentId'].isna().sum()

print(f"Number of missing values in 'FK_ContentId': {missing_values_count}")
# Out:
# Number of missing values in 'FK_ContentId': 1

# %%
missing_rows = transactions[transactions['FK_ContentId'].isna()]

missing_rows.head()
# Out:
#         TrxId                 TrxDate  FK_BusinessUserId  PointsRedeemed  \
# 290  16005301 2023-10-31 00:13:46.780             990848            5000
#
#                  EntityName  FK_ContentId EntityCategory
# 290  Al Oula petrol station           NaN            NaN

# %%
replacement_value = 115099

# Replace missing 'FK_ContentId' values with the specified value in the main dataframe
transactions.loc[transactions['FK_ContentId'].isna(), 'FK_ContentId'] = replacement_value

# Verify the changes
updated_missing_rows = transactions[transactions['FK_ContentId'] == replacement_value]
updated_missing_rows.head()
# Out:
#        TrxId                 TrxDate  FK_BusinessUserId  PointsRedeemed  \
# 43  15966805 2023-10-30 01:36:08.077             986005            5000
# 44  15966513 2023-10-30 01:36:21.933             984518            5000
# 45  15966849 2023-10-30 01:41:07.643             985948            5000
# 46  15966838 2023-10-30 01:41:25.657             985278            5000
# 47  15966225 2023-10-30 01:48:28.113             985583            5000
#
#                 EntityName  FK_ContentId EntityCategory
# 43  Al Oula petrol station      115099.0            NaN
# 44  Al Oula petrol station      115099.0            NaN
# 45  Al Oula petrol station      115099.0            NaN
# 46  Al Oula petrol station      115099.0            NaN
# 47  Al Oula petrol station      115099.0            NaN

# %%
transactions['FK_ContentId'] = transactions['FK_ContentId'].astype(int)
transactions.head()
# Out:
#       TrxId                 TrxDate  FK_BusinessUserId  PointsRedeemed  \
# 0  12429817 2023-06-04 11:46:06.050             976480            1000
# 1  12525687 2023-06-07 14:08:10.287             976480           10000
# 2  12525666 2023-06-08 11:03:32.043             976480           10000
# 3  12838074 2023-06-22 08:28:30.300             976921              10
# 4  13587992 2023-07-27 14:41:13.607             976480              50
#
#         EntityName  FK_ContentId   EntityCategory
# 0  Alkhalid Clinic        113923  Health & Beauty
# 1        H&S Store        113853      Electronics
# 2        H&S Store        113853      Electronics
# 3   Deliveroo Plus        113851  Food & Beverage
# 4       Mawqif App        113835        On-demand

# %%
transactions['TrxDate'] = pd.to_datetime(transactions['TrxDate'])

# %%
transactions['Month'] = transactions['TrxDate'].dt.month

# %%
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Fall'
    

# Apply the function to create a 'Season' column
transactions['Season'] = transactions['Month'].apply(get_season)

# %%
transactions.head(10)
# Out:
#       TrxId                 TrxDate  FK_BusinessUserId  PointsRedeemed  \
# 0  12429817 2023-06-04 11:46:06.050             976480            1000
# 1  12525687 2023-06-07 14:08:10.287             976480           10000
# 2  12525666 2023-06-08 11:03:32.043             976480           10000
# 3  12838074 2023-06-22 08:28:30.300             976921              10
# 4  13587992 2023-07-27 14:41:13.607             976480              50
# 5  13901731 2023-08-09 14:41:55.927             976518            5000
# 6  13950319 2023-08-10 15:46:13.423             976921              50
# 7  14235910 2023-08-22 18:40:51.507             976921              10
# 8  14455067 2023-08-31 12:55:37.173             976921              10
# 9  14568055 2023-09-04 09:44:15.030             976921              10
#
#         EntityName  FK_ContentId   EntityCategory  Month  Season
# 0  Alkhalid Clinic        113923  Health & Beauty      6  Summer
# 1        H&S Store        113853      Electronics      6  Summer
# 2        H&S Store        113853      Electronics      6  Summer
# 3   Deliveroo Plus        113851  Food & Beverage      6  Summer
# 4       Mawqif App        113835        On-demand      7  Summer
# 5         COFE App        113834        On-demand      8  Summer
# 6       Mawqif App        113835        On-demand      8  Summer
# 7   Deliveroo Plus        113851  Food & Beverage      8  Summer
# 8   Deliveroo Plus        113851  Food & Beverage      8  Summer
# 9   Deliveroo Plus        113851  Food & Beverage      9    Fall

# %%
# Aggregate the number of transactions per FK_ContentId per season
content_season_counts = transactions.groupby(['FK_ContentId', 'Season']).size().reset_index(name='TransactionCount')

# Find the most active season for each FK_ContentId
most_active_season = content_season_counts.loc[content_season_counts.groupby('FK_ContentId')['TransactionCount'].idxmax()]

# Merge with the original DataFrame to keep the FK_ContentId details
transactions = transactions.merge(most_active_season[['FK_ContentId', 'Season']], on='FK_ContentId', suffixes=('', '_MostActiveSeason'))

# Rename the column for clarity
transactions = transactions.rename(columns={'Season_MostActiveSeason': 'MostActiveSeason'})

# %%
transactions[['FK_ContentId', 'MostActiveSeason']].drop_duplicates().head()
# Out:
#    FK_ContentId MostActiveSeason
# 0        113923           Summer
# 1        113853           Spring
# 3        113851           Spring
# 4        113835             Fall
# 5        113834           Spring

# %%
# Determine if the transaction date is a weekday or weekend
transactions['DayOfWeek'] = transactions['TrxDate'].dt.dayofweek
transactions['IsWeekend'] = transactions['DayOfWeek'] >= 5

# Count transactions for weekdays and weekends per FK_ContentId
content_activity = transactions.groupby(['FK_ContentId', 'IsWeekend']).size().unstack(fill_value=0)
content_activity.columns = ['WeekdayTransactionCount', 'WeekendTransactionCount']

# Reset index to make FK_ContentId a column again
content_activity = content_activity.reset_index()

# %%
# Merge with the original DataFrame to include content activity details
transactions = transactions.merge(content_activity, on='FK_ContentId', how='left')

# Optionally, drop the intermediate 'DayOfWeek' and 'IsWeekend' columns if no longer needed
transactions = transactions.drop(columns=['DayOfWeek', 'IsWeekend'])

# %%
# Create a new column to indicate more active period
def determine_activity_preference(row):
    if row['WeekdayTransactionCount'] > row['WeekendTransactionCount']:
        return 'Weekdays'
    elif row['WeekendTransactionCount'] > row['WeekdayTransactionCount']:
        return 'Weekends'
    else:
        return 'Equal'

# Apply the function to create a new column
transactions['ActivityPreference'] = transactions.apply(determine_activity_preference, axis=1)

# %%
transactions.head()
# Out:
#       TrxId                 TrxDate  FK_BusinessUserId  PointsRedeemed  \
# 0  12429817 2023-06-04 11:46:06.050             976480            1000
# 1  12525687 2023-06-07 14:08:10.287             976480           10000
# 2  12525666 2023-06-08 11:03:32.043             976480           10000
# 3  12838074 2023-06-22 08:28:30.300             976921              10
# 4  13587992 2023-07-27 14:41:13.607             976480              50
#
#         EntityName  FK_ContentId   EntityCategory  Month  Season  \
# 0  Alkhalid Clinic        113923  Health & Beauty      6  Summer
# 1        H&S Store        113853      Electronics      6  Summer
# 2        H&S Store        113853      Electronics      6  Summer
# 3   Deliveroo Plus        113851  Food & Beverage      6  Summer
# 4       Mawqif App        113835        On-demand      7  Summer
#
#   MostActiveSeason  WeekdayTransactionCount  WeekendTransactionCount  \
# 0           Summer                        0                        1
# 1           Spring                        4                        2
# 2           Spring                        4                        2
# 3           Spring                     4140                     1736
# 4             Fall                       14                        0
#
#   ActivityPreference
# 0           Weekends
# 1           Weekdays
# 2           Weekdays
# 3           Weekdays
# 4           Weekdays

# %%
Redemption_data = pd.read_excel(Path(SOURCEDATA / "Rdepemtion_Cleaned_Deals.xlsx"))

# %%
Redemption_data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  ContentId  \
# 0             0           0     113815
# 1             1           1     113816
# 2             2           2     113817
# 3             3           3     113818
# 4             4           4     113819
#
#                                     Title  FK_StatusId Deal Type  \
# 0                       Off from Al Rifai            2   Voucher
# 1                      Off from Dip n dip            2   Voucher
# 2  Order from Dip n Dip and get  discount            1  Discount
# 3        Get  discount from Ellena Bakery            2  Discount
# 4                        Off from Talabat            1   Voucher
#
#                                          Description  \
# 0  Get a 15 KD discount voucher for your next onl...
# 1  Get 10 KD off on your next order from Dip n di...
# 2          Order from Dip n Dip and get 5KD discount
# 3                Get 3KD discount from Ellena Bakery
# 4                     Get 3KD discount from Talabat.
#
#                                             Location  Points  \
# 0  https://www.google.com/maps/search/al+rifai+ku...   15000
# 1                                                NaN   10000
# 2  https://www.google.com/maps/search/dipndip/@29...    5000
# 3          https://maps.app.goo.gl/bnZXdfUbbaGFjFiJA    3000
# 4              https://goo.gl/maps/5uoJEdD95W1YSpDt9    3000
#
#                       Categories
# 0       Food and Beverage Stores
# 1  Restaurants and Food Services
# 2  Restaurants and Food Services
# 3       Food and Beverage Stores
# 4  Restaurants and Food Services

# %%
# Rename 'ContentId' in Redemption_data to match 'FK_ContentId' in transactions
Redemption_data = Redemption_data.rename(columns={'ContentId': 'FK_ContentId'})

# Merge the dataframes on 'FK_ContentId'
merged_df = pd.merge(transactions, Redemption_data[['FK_ContentId', 'Categories']], on='FK_ContentId', how='left')

# %%
transactions['EntityCategory'] = merged_df['Categories']
transactions.head()
# Out:
#       TrxId                 TrxDate  FK_BusinessUserId  PointsRedeemed  \
# 0  12429817 2023-06-04 11:46:06.050             976480            1000
# 1  12525687 2023-06-07 14:08:10.287             976480           10000
# 2  12525666 2023-06-08 11:03:32.043             976480           10000
# 3  12838074 2023-06-22 08:28:30.300             976921              10
# 4  13587992 2023-07-27 14:41:13.607             976480              50
#
#         EntityName  FK_ContentId                 EntityCategory  Month  \
# 0  Alkhalid Clinic        113923             Health and Medical      6
# 1        H&S Store        113853     Electronics and Appliances      6
# 2        H&S Store        113853     Electronics and Appliances      6
# 3   Deliveroo Plus        113851  Restaurants and Food Services      6
# 4       Mawqif App        113835          Ground Transportation      7
#
#    Season MostActiveSeason  WeekdayTransactionCount  WeekendTransactionCount  \
# 0  Summer           Summer                        0                        1
# 1  Summer           Spring                        4                        2
# 2  Summer           Spring                        4                        2
# 3  Summer           Spring                     4140                     1736
# 4  Summer             Fall                       14                        0
#
#   ActivityPreference
# 0           Weekends
# 1           Weekdays
# 2           Weekdays
# 3           Weekdays
# 4           Weekdays

# %%
#transactions.to_excel(Path(SOURCEDATA / "Redemptions_Transactions_For_Profilings.xlsx") , index=False)
